# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Notebook settings
sns.set(style="whitegrid")

# Load dataset
df = pd.read_csv("../EDA/depressed_with_anxiety_labels.csv")

# Quick shape & preview
print("Shape of Data:", df.shape)
df.head()
# Out:
# Shape of Data: (29, 404)
#    participant_id   sadness     anger       joy      fear  nervousness  \
# 0  308_TRANSCRIPT  0.771332  0.784027  0.001125  0.212598     0.519310
# 1  309_TRANSCRIPT  0.983808  1.000000  0.000000  0.271162     0.264945
# 2  311_TRANSCRIPT  0.426572  0.000000  0.000000  0.000000     0.000000
# 3  319_TRANSCRIPT  0.201385  0.000000  0.001468  0.277533     0.542340
# 4  320_TRANSCRIPT  0.544218  0.921958  0.002646  1.000000     0.732804
#
#    affection  negative_emotion  positive_emotion  confusion  ...  embed_378  \
# 0   0.002250          0.667230          0.006749   0.153206  ...  -0.020888
# 1   0.001435          0.821376          0.012912   0.195409  ...  -0.111993
# 2   0.000000          0.529259          0.001555   0.000000  ...   0.007027
# 3   0.001468          0.280457          0.007342   1.000000  ...  -0.053243
# 4   0.003968          1.000000          0.013228   0.180159  ...   0.004624
#
#    embed_379  embed_380  embed_381  embed_382  embed_383  phq8_score  \
# 0  -0.005703  -0.004676   0.019968  -0.066287  -0.020669          22
# 1   0.017624   0.018996   0.025255   0.018172  -0.036503          15
# 2  -0.011035   0.060791   0.130841  -0.038660   0.006578          21
# 3   0.035062   0.060516   0.077625  -0.101533   0.031449          13
# 4   0.045622   0.083397   0.074724  -0.062993  -0.033380          11
#
#    phq8_binary  anxiety_score  anxiety_binary
# 0            1       0.517951               1
# 1            1       0.589450               1
# 2            1       0.159305               0
# 3            1       0.383619               0
# 4            1       0.729856               1
#
# [5 rows x 404 columns]

# %%
# Check for nulls
print("\nMissing Values:\n", df.isnull().sum())
# Out:
# Missing Values:
#  participant_id    0
# sadness           0
# anger             0
# joy               0
# fear              0
#                  ..
# embed_383         0
# phq8_score        0
# phq8_binary       0
# anxiety_score     0
# anxiety_binary    0
# Length: 404, dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Columns: 404 entries, participant_id to anxiety_binary
# dtypes: float64(400), int64(3), object(1)
# memory usage: 91.7+ KB
#
# Anxiety Score Description:
#  count    29.000000
# mean      0.364577
# std       0.154918
# min       0.104904
# 25%       0.240829
# 50%       0.358613
# 75%       0.505437
# max       0.729856
# Name: anxiety_score, dtype: float64

# %%
# Data types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Columns: 404 entries, participant_id to anxiety_binary
# dtypes: float64(400), int64(3), object(1)
# memory usage: 91.7+ KB

# %%
# Describe key scores
print("\nAnxiety Score Description:\n", df['anxiety_score'].describe())
# Out:
# Anxiety Score Description:
#  count    29.000000
# mean      0.364577
# std       0.154918
# min       0.104904
# 25%       0.240829
# 50%       0.358613
# 75%       0.505437
# max       0.729856
# Name: anxiety_score, dtype: float64

# %%
df['anxiety_binary'].value_counts()
# Out:
# anxiety_binary
# 0    21
# 1     8
# Name: count, dtype: int64
