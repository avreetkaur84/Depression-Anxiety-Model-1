# %%
import pandas as pd

# Load the full feature set
df = pd.read_csv("../EDA/final_features_with_labels.csv")

print("Shape of dataset:", df.shape)
df.head()
# Out:
# Shape of dataset: (8, 402)
#    participant_id   sadness     anger       joy      fear  nervousness  \
# 0             301  0.000000  0.000000  0.000678  0.000678     0.004746
# 1             303  0.000509  0.000000  0.000000  0.000000     0.004580
# 2             304  0.002026  0.000000  0.001013  0.001013     0.003040
# 3             305  0.001804  0.000301  0.000000  0.000301     0.000902
# 4             308  0.005624  0.001125  0.001125  0.001125     0.005624
#
#    affection  negative_emotion  positive_emotion  confusion  ...  embed_376  \
# 0   0.000678          0.018983          0.010847   0.003390  ...  -0.077552
# 1   0.000509          0.009160          0.011705   0.000509  ...  -0.045040
# 2   0.003040          0.016211          0.013171   0.000000  ...  -0.001942
# 3   0.001804          0.006915          0.006013   0.000301  ...  -0.022700
# 4   0.002250          0.016873          0.006749   0.001125  ...  -0.012394
#
#    embed_377  embed_378  embed_379  embed_380  embed_381  embed_382  \
# 0   0.048985  -0.061061   0.039652   0.019754   0.050870  -0.025160
# 1  -0.010693  -0.064340   0.095692  -0.012720   0.009505  -0.009843
# 2   0.075825  -0.045645   0.021254  -0.002397   0.064429  -0.025121
# 3   0.058585  -0.016208   0.008010   0.013218   0.035188  -0.065164
# 4   0.051637  -0.020888  -0.005703  -0.004676   0.019968  -0.066287
#
#    embed_383  phq8_score  phq8_binary
# 0   0.033991           3            0
# 1   0.043166           0            0
# 2   0.029481           6            0
# 3  -0.005411           7            0
# 4  -0.020669          22            1
#
# [5 rows x 402 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Columns: 402 entries, participant_id to phq8_binary
# dtypes: float64(399), int64(3)
# memory usage: 25.3 KB

# %%
df[["phq8_score", "phq8_binary"]].describe()
# Out:
#        phq8_score  phq8_binary
# count    8.000000     8.000000
# mean     9.750000     0.375000
# std      8.447316     0.517549
# min      0.000000     0.000000
# 25%      3.750000     0.000000
# 50%      6.500000     0.000000
# 75%     16.500000     1.000000
# max     22.000000     1.000000

# %%
# Count missing values per column
missing_values = df.isnull().sum()
missing_cols = missing_values[missing_values > 0]
print("Columns with missing values:\n", missing_cols)

# Total missing values
print("\nTotal missing values in dataset:", df.isnull().sum().sum())
# Out:
# Columns with missing values:
#  Series([], dtype: int64)
#
# Total missing values in dataset: 0

# %%
# Check distribution of target (binary and score)
print("PHQ8 Score distribution:\n", df["phq8_score"].value_counts().sort_index())
print("\nPHQ8 Binary distribution:\n", df["phq8_binary"].value_counts())
# Out:
# PHQ8 Score distribution:
#  phq8_score
# 0     1
# 3     1
# 4     1
# 6     1
# 7     1
# 15    1
# 21    1
# 22    1
# Name: count, dtype: int64
#
# PHQ8 Binary distribution:
#  phq8_binary
# 0    5
# 1    3
# Name: count, dtype: int64

# %%
# Check for duplicate rows
print("Number of duplicate rows:", df.duplicated().sum())
# Out:
# Number of duplicate rows: 0

# %%
# Check that embedding columns exist and have valid values
embed_cols = [col for col in df.columns if col.startswith("embed_")]
print("Total embedding columns:", len(embed_cols))

# Check for any NaNs or infinite values in embeddings
nan_embed = df[embed_cols].isnull().sum().sum()
inf_embed = ((df[embed_cols] == float("inf")) | (df[embed_cols] == float("-inf"))).sum().sum()

print("Missing in embeddings:", nan_embed)
print("Infinite in embeddings:", inf_embed)
# Out:
# Total embedding columns: 384
# Missing in embeddings: 0
# Infinite in embeddings: 0

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
df[embed_cols] = scaler.fit_transform(df[embed_cols])

# %%
df.head()
# Out:
#    participant_id   sadness     anger       joy      fear  nervousness  \
# 0             301  0.000000  0.000000  0.000678  0.000678     0.004746
# 1             303  0.000509  0.000000  0.000000  0.000000     0.004580
# 2             304  0.002026  0.000000  0.001013  0.001013     0.003040
# 3             305  0.001804  0.000301  0.000000  0.000301     0.000902
# 4             308  0.005624  0.001125  0.001125  0.001125     0.005624
#
#    affection  negative_emotion  positive_emotion  confusion  ...  embed_376  \
# 0   0.000678          0.018983          0.010847   0.003390  ...  -1.635961
# 1   0.000509          0.009160          0.011705   0.000509  ...  -0.625594
# 2   0.003040          0.016211          0.013171   0.000000  ...   0.713727
# 3   0.001804          0.006915          0.006013   0.000301  ...   0.068639
# 4   0.002250          0.016873          0.006749   0.001125  ...   0.388898
#
#    embed_377  embed_378  embed_379  embed_380  embed_381  embed_382  \
# 0   0.111204  -0.400292   0.586673   0.021751   0.215121   0.383090
# 1  -2.200371  -0.495034   2.332442  -1.213782  -0.866383   0.858006
# 2   1.150830   0.045167   0.013509  -0.821047   0.569646   0.384299
# 3   0.483057   0.895783  -0.399060  -0.226936  -0.194882  -0.857282
# 4   0.213920   0.760535  -0.826242  -0.907745  -0.592816  -0.892106
#
#    embed_383  phq8_score  phq8_binary
# 0   1.096271           3            0
# 1   1.416321           0            0
# 2   0.938950           6            0
# 3  -0.278265           7            0
# 4  -0.810561          22            1
#
# [5 rows x 402 columns]
